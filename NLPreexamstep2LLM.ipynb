# %% [markdown]
# Step2: LLM-based structured extraction (ollama gemma3:4b)
# - Using ollama gemma3:4b as it is goog to perform speech-level structured extraction
# - After that save the output as CSV file to continue on COLAB for KG and network analysis.

# %%
import pandas as pd
import os
import json
import subprocess #from chatGPT

# %%
df = pd.read_csv("eu_debates_2020_clean.csv")
print("Total speeches:", len(df)) #after cleaning all the N/A rows
df.head()
# Out:
# Total speeches: 7012
#           speaker_name speaker_role speaker_party intervention_language  \
# 0    Rasa Juknevičienė          MEP           PPE                    lt
# 1           Tomas Tobé          MEP           PPE                    en
# 2  Iratxe García Pérez          MEP           S&D                    es
# 3         Joëlle Mélin          MEP            ID                    fr
# 4      Petros Kokkalis          MEP       GUE/NGL                    en
#
#   original_language        date  year                debate_title  \
# 0                lt  2020-01-13  2020  Statement by the President
# 1                en  2020-01-13  2020           Order of business
# 2                es  2020-01-13  2020           Order of business
# 3                fr  2020-01-13  2020           Order of business
# 4                en  2020-01-13  2020           Order of business
#
#                                                 text  \
# 0   – 1991-ųjų metų Sausio 13-oji iš esmės buvo p...
# 1  on behalf of the PPE Group. – Mr President, Sw...
# 2   – Señor presidente, a mí lo que me parece lam...
# 3  au nom du groupe ID. – Monsieur le Président, ...
# 4   – Mr President, unfortunately the nightmare t...
#
#                                      translated_text  \
# 0   January 13, 1991 was essentially the last of ...
# 1                                                NaN
# 2   “Mr. President, what seems regrettable to me ...
# 3  on behalf of the ID group. “Mr. President, my ...
# 4                                                NaN
#
#                                        analysis_text  mentions_health_kw
# 0   January 13, 1991 was essentially the last of ...               False
# 1  on behalf of the PPE Group. – Mr President, Sw...               False
# 2   “Mr. President, what seems regrettable to me ...               False
# 3  on behalf of the ID group. “Mr. President, my ...               False
# 4   – Mr President, unfortunately the nightmare t...               False

# %%
texts = df["analysis_text"].dropna().tolist()
texts[:20]
# Out:
# [' January 13, 1991 was essentially the last of the Battle of the Second World War. It was delayed because it had been almost fifty years since the Ribentropo-Molotov Pact, but won.  Thank you, Mr. President, that you entered the unforgettable, which many of my colleagues have entered today. Today, January 13 is not just the day of tragic losses, although after the tanks, the defenders were killed or wounded. Today is a day of victory for us, setting the way to the European Union and NATO. Finally, the Second World War ended two years later – the first of the ninety-third of September, when the Soviet army was taken out of Lithuania. This memorandum is a sign of respect and remembrance to all the victims of Soviet communism: from the Baltics, Poland to Romania, Bulgaria, Albania, and also to millions of killed in Russia itself. Today I am a good opportunity to thank all the colleagues who voted for an important resolution on the actions of the Russian Federation against the investigators and judges of the January 13 case in November. Your solidarity is an important European value.',
#  'on behalf of the PPE Group. – Mr\xa0President, Sweden has serious problems with violence connected to organised crime, and the city of Malmö is particularly affected. Bombings and shootings are now part of everyday life in Malmö. Last year, the Danish Government introduced border controls against Sweden to protect Danish citizens from Swedish gang members. This is a unique decision. No other government in Europe has so clearly pointed out gang members in a neighbouring country as the reason to have border controls. The PPE believes that the escalating violence in Malmö and Copenhagen should be mentioned in the title of the debate on cross-border crime, and we ask for a roll call vote on this matter. The fact that the S&D Group doesn’t want the problems in Malmö to be mentioned in the title is deeply regrettable. Let’s take the chance in this Parliament and change this today. We have serious problems to handle and it’s important for Sweden, Denmark and Europe. (Applause)',
#  ' “Mr. President, what seems regrettable to me is that we try to use this turn, which enables to modify the order of the day, to, for the third time in a row, try to win a vote that has already been lost in two occasions. And I say this because the Group of the European People’s Party has attempted twice to transfer this issue to the Conference of Presidents and the other groups have clearly told us what our position is. If necessary, we will repeat it again. We believe it is important to talk about the dangers of organized crime, but without the need to criminalize a specific issue and attack a specific city, in this case. So continue to insist. This political group will continue to hold the same position. ',
#  'on behalf of the ID group. “Mr. President, my dear colleagues, in the face of the nightmare news of a kissing continent, where thousands of animals, insects and plants have gone into smoke in a few weeks and where human lives are seriously threatened, we have the collective duty to react. This reaction can find its foundation in the European culture of solidarity, which is more with this great friend country that is Australia. The architecture and the modalities of the rescEU program, although it is theoretically reserved for the Member States, allow it. It is the idea of sending exceptional logistical and operational capabilities to this continent to fight flames. Also, please support, dear colleagues, this title amendment for our declaration to the Commission on these devastating fires in Australia.',
#  ' – Mr\xa0President, unfortunately the nightmare that is happening in Australia does not happen by itself, it happens because of climate change. Therefore, we disagree with removing the title. However, we do believe that we have a moral responsibility to use rescEU all over the world in all possible means. So we would not object to the rescEU part being a part of the title, but we would object to removing the reference to climate change from the title.',
#  'on behalf of the GUE/NGL group. The European Parliament voted a resolution against police violence in the European Union. We see today, everywhere in Europe, protesters who are mismanaged and violated by the police, and I think especially of Greek, Belgian, Romanian, Polish, French and so many others. Despite the condemnations by the UN, NGOs, Amnesty International, the European Court of Human Rights or the Human Rights Defender, I would like to remind you of a picture that we have seen this week: a young girl who is raped and bullied by the law enforcement forces or even the end-to-end shootings of defensive bullets (LBDs). Our GUE group and the delegation France insoumise therefore call for a debate and a resolution on the prohibition of LBDs, de-circle grenades and wind plaque, which are prohibited in some countries. The use of force, I remind, must be proportionate and therefore, my dear colleagues, as we are going to talk about text on fundamental freedoms this week, I remind you that the right to demonstrate is a fundamental freedom that the European Union must guarantee.',
#  ' Mr President! My way! I want to say that you used the name of my country: Poland. In Poland, the demonstrations take place peacefully and are not suppressed by the police, but protected. However, if it comes to the issue of the rule of law in France, we agree, but we have our own proposal and I hope that Mr. President will allow me to submit it on behalf of the ECR group at the right time. This is also a matter of changing the agenda on Wednesday.',
#  ' Is it possible to ask for a separate vote? Because the proposal, as we understand, is a debate with resolution. We would be ready to make the debate, but not that there would be a resolution. So, if possible, we ask to separate the vote, and we would support the debate.',
#  'on behalf of the ECR Group. Mr President! In connection with the use of force against defensive lawyers and lawyers in the court building in Paris and the previous brutal pacifications of the protesters, so-called yellow camisels, on behalf of the ECR group, I propose a debate with the adoption of a resolution on the state of rule of law in France. I remind you that the right to manifest and to express their opinions is the foundation of the European Union, specially stipulated in Article 12 of the Charter of Fundamental Rights, which guarantees to everyone the right to free and peaceful assembly. The authorities in France, using force against their own citizens and lawyers, violate the above principles, which are also revoked by the Treaty on the European Union and the Lisbon Treaty. So let’s look at whether the same rules and the same law are applied to large EU countries, such as France, as to smaller countries, where – I remind – the protests are not suppressed. Is the principle of equality respected? I ask for a nominal vote so that everyone can speak openly about whether he supports physical attacks on undefenced lawyers in France.',
#  'The problem in Australia is not the fire itself, it is a part of the Australian nature for a long time. Butterfly, forests and Australian unique species are adapted to it. The problem is the large-scale range of fires allowed in two extremely warm and dry years. The average summer temperature was four degrees higher than normal. I would like to say, “Welcome to the future.” In the near future, this scenario will be common, fires will repeat, their scope, intensity and frequency will increase. If we do not start effectively reducing carbon emissions and do not allow nature to adapt to changing conditions to a maximum extent, Australia will be a terrible example of the failure of an economic model incompatible with life on our planet. The reform must be a global initiative that is consistently transformed into national policies. Let’s not be subject to the illusion that it doesn’t affect us, that Australia is too distant and exotic. This smallest continent in that, unfortunately, won’t stay alone.',
#  ' – Madam\xa0President, massive wildfires have been raging through the country in recent months. Since last September, 28 people have died and thousands have lost their homes. Firefighters are risking their own lives to keep people safe. Our sympathy is with the Australian people in these difficult times. Not rain, but ash is falling from the skies of Australia. We all know that these extreme bush fires cannot be viewed separately from climate change. This is not a casual emergency – this is a climate emergency, stemming from a climate crisis. Now the question is whether these catastrophic fires will bring some sanity to Australian climate politics. The Conservative government, led by Prime Minister Morrison, has done nothing to meet its climate commitments. During the UN climate talks in Madrid, ‘ScoMo’ sided with Brazil and Saudi Arabia to derail global action on cutting emissions. How can a Prime Minister make fear of the costs of climate action more terrifying than the actual results of climate change themselves? Of course, this is not only an Australian problem. It is related to one of the biggest global challenges of our time, in which we all bear responsibility. The devastating Australian fires underline the magnitude of the effects of inaction at the recent COP 25 Climate Conference. This only makes it more important for us, as the EU, to lead and set a standard for the rest of the world. But the European Green Deal is not and cannot be only about Europe – climate diplomacy must become an integral part of our external policy and a fundamental pillar of our soft power around the globe. There is no time to waste anymore. Leading by example we must bring all of our partners with us for common, bold political action on the climate crisis.',
#  ' “Mr President, do you hear this scream, even 17,000 kilometers from Australia? Do we hear the pain of the families of human victims and the suffering of the victims who have completely lost everything? Do we hear the screams of a billion carbonized animals? It’s a shocking cry, it’s a shocking SOS that sounds like a planetary alarm cry and it’s exactly in this way that we must hear the Australian drama that, despite it, makes the demonstration that we are right to build a European Green Pact. You know, 300,000 European citizens live two hours from Sydney, New Caledonia: they are – and we are, therefore – the first neighbors and the first witnesses of the disaster. Today, in Europe, we must mobilize in the name of solidarity, of course, but the reality is that we need an obligation of collective intelligence and a political mobilization. While we have just declared the climate emergency, how not to understand that if we do not accelerate our fight against climate disorder, the Australian disaster will be our planetary drama tomorrow. How not to understand that we must fight climate skeptics all over the world, including here, because the consequences of ecological dramas have no boundaries: from Australia to Chile, a toxic cloud has just crossed the world’s largest ocean, a ocean rich in biodiversity. I want to remind that 80% of European biodiversity comes from overseas: with this legitimacy I reaffirm the need for concrete actions to protect the environment and future generations and with this assumed optimism I declare that the European Green Pact must rely on overseas which are solutions territories.']

# %% [markdown]
# - Select sample size at 1000 speeches to be good anough to see patterns but runable locally

# %%
df_sample = df.sample(1000, random_state=42).reset_index(drop=True)
print("sample size:", len(df_sample))
# Out:
# sample size: 1000

# %% [markdown]
# - Built the prompt for LLM to extract the scpeeches mentioned COVID-19 or health issues

# %%
def build_prompt(text):
    return f"""
You are an expert in political science and natural language processing. Your task is to analyze the following speech text from a European Parliament debate and extract,
Task: Decide wether the sceeph discusses 
- COVID-19
- public health issues
- vaccination
- healthcare systems
- hospitals
- public health emergency
- dicease control
- pandemic
- health policies

Do not include other topics e.g. environment or climate change unless they are explicitly linked to COVID-19 or public health.

Return ONLY valid JSON in the following format:
{{
  "health_mentioned": true or false,
  "health_topics": [list of short topic phrase]
}}
Speech:
\"\"\"{text[:3000]}\"\"\"
"""

# %% [markdown]
# #code suggested and debug (uft-8) by chat gpt

# %%
def query_ollama(prompt, model="gemma3:4b"):
    result = subprocess.run(
        ["ollama", "run", model],
        input=prompt,
        text=True,
        encoding="utf-8",        
        capture_output=True
    )
    return result.stdout.strip()

# %%
test_text = df_sample.loc[0, "analysis_text"]
prompt = build_prompt(test_text)
response = query_ollama(prompt)
print(response)
# Out:
# ```json
# {
#   "health_mentioned": true,
#   "health_topics": [
#     "public health",
#     "healthcare systems",
#     "health policies",
#     "disease control",
#     "pandemic",
#     "health crisis"
#   ]
# }
# ```

# %% [markdown]
# #code parse output debug by chatgpt

# %%
def parse_output(output):
    try:
        cleaned = re.sub(r"```json|```", "", output).strip()
        data = json.loads(cleaned)

        discusses = (
            data.get("health_mentioned")
            or data.get("health_mention")
            or data.get("discusses_health_issues")
        )

        topics = data.get("health_topics", [])

        if not isinstance(discusses, bool):
            discusses = None
        if not isinstance(topics, list):
            topics = []

        return {
            "health_mentioned": discusses,
            "health_topics": topics
        }

    except Exception as e:
        print("PARSING ERROR:", e)
        print("RAW OUTPUT:", output)
        return {
            "health_mentioned": None,
            "health_topics": []
        }

# %%
row = df_sample.iloc[0]
raw = query_ollama(build_prompt(row["analysis_text"]))
print("RAW:")
print(raw)

print("PARSED:")
print(parse_output(raw))
# Out:
# RAW:
# ```json
# {
#   "health_mentioned": true,
#   "health_topics": [
#     "public health",
#     "healthcare systems",
#     "health policies",
#     "disease control",
#     "pandemic",
#     "COVID-19"
#   ]
# }
# ```
# PARSED:
# {'health_mentioned': True, 'health_topics': ['public health', 'healthcare systems', 'health policies', 'disease control', 'pandemic', 'COVID-19']}

# %%
results = []

for i, row in df_sample.iterrows():
    raw = query_ollama(build_prompt(row["analysis_text"]))
    parsed = parse_output(raw)

    results.append({
        "speaker_party": row["speaker_party"],
        "health_mentioned": parsed["health_mentioned"],
        "health_topics": parsed["health_topics"]
    })

    if i % 50 == 0:
        print(f"Processed {i} / {len(df_sample)}")

llm_df = pd.DataFrame(results)
# Out:
# Processed 0 / 1000
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# This speech focuses solely on border security, migration control, and crime prevention. It does not discuss any aspects of COVID-19, public health, vaccination, healthcare systems, hospitals, public health emergencies, disease control, pandemics, or health policies. Therefore, the `health_mentioned` flag is set to `false`, and the `health_topics` list is empty.
# Processed 50 / 1000
# Processed 100 / 1000
# Processed 150 / 1000
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# This speech does not contain any explicit references to health-related topics. It focuses solely on economic comparisons related to Brexit and the performance of the UK and EU economies. Therefore, all the requested topic flags are set to `false`.
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# This speech focuses entirely on geopolitical and diplomatic concerns, specifically relating to the situation in Iraq and Iran. There is no mention of COVID-19, public health, healthcare, disease control, or any related health topics. Therefore, the `health_mentioned` flag is set to `false`, and the `health_topics` list remains empty.
# Processed 200 / 1000
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# This speech does not directly address any of the specified health-related topics. It focuses solely on immigration, the relationship with Turkey, and the need for a political solution to the refugee crisis.  While the context of immigration and border security *can* relate to public health (e.g., disease spread among migrants), this speech does not explicitly discuss any of the targeted health issues.
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# The speech focuses entirely on the geopolitical situation in Syria, the EU's relationship with Turkey, and migration issues. There is absolutely no mention of any health-related topics, including COVID-19, public health, vaccination, healthcare systems, hospitals, public health emergencies, disease control, pandemics, or health policies. The discussion of the displacement of Kurds and Christians is presented as a humanitarian concern, but it doesn't relate to any health aspects.
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# This speech focuses entirely on political accountability (accusations of financial abuse against Prime Minister Babiš) and the role of the European Commission.  It does *not* discuss any health-related topics, including COVID-19, public health issues, vaccination, healthcare systems, hospitals, public health emergencies, disease control, pandemics, or health policies.  The mention of the "European Commission verifying its consumption" is purely in the context of financial oversight, not health.
# Processed 250 / 1000
# Processed 300 / 1000
# Processed 350 / 1000
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# This speech does not directly address any of the specified health-related topics. It focuses entirely on labor market issues, immigration, and economic recovery following a "crisis" (presumably referring to the broader economic impacts, not COVID-19 specifically).  There are no mentions of COVID-19, public health, vaccination, healthcare systems, hospitals, public health emergencies, disease control, pandemics, or health policies. The reference to "unemployed citizens affected by the crisis" is a general economic observation, not a health-related one.
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# This speech focuses entirely on geopolitical tensions and conflict in the Caucasus region. It does not address any of the topics specified in the prompt (COVID-19, public health issues, vaccination, healthcare systems, hospitals, public health emergency, disease control, pandemic, or health policies).  There are no references to health or medical matters.
# Processed 400 / 1000
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# The speech focuses entirely on political events in Belarus, specifically concerning civil rights, democracy, and police brutality. It references a Catalan protest song and political figures involved in that movement. There is no mention of any health-related topics, including COVID-19, public health, vaccination, healthcare systems, hospitals, public health emergencies, disease control, pandemics, or health policies.
# Processed 450 / 1000
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# The speech focuses entirely on foreign policy, geopolitical strategy, and the EU's role in international relations.  It does not mention any topics related to healthcare, public health, COVID-19, vaccination, or any other health-related issues. Therefore, all the "health_mentioned" flags are false.
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# This speech focuses entirely on the rule of law, financial contributions to the European project, and safeguarding democratic institutions. It does not contain any explicit references to COVID-19, public health, vaccination, healthcare systems, hospitals, public health emergencies, disease control, pandemics, or health policies. Therefore, the `health_mentioned` field is set to `false` and the `health_topics` list is empty.
# Processed 500 / 1000
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# This speech focuses primarily on indigenous rights, climate change, and corporate responsibility.  It does *not* directly address any of the specified health topics (COVID-19, public health issues, vaccination, healthcare systems, hospitals, public health emergency, disease control, pandemic, or health policies). While the mention of "nature" implicitly relates to environmental health, the core discussion is not about health or healthcare.
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# This speech excerpt does not contain any explicit references to health, diseases, or related topics. It focuses entirely on procedural issues within the European Parliament debate regarding the allocation of time for a discussion on "culture".  Therefore, none of the requested topics are present.
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# The speech excerpt focuses solely on a specific incident ("defeat of the Ukrainian aircraft from 'Pech'") and a question regarding an apology to civilian victims. It does not contain any direct references or implications related to COVID-19, public health issues, vaccination, healthcare systems, hospitals, public health emergencies, disease control, a pandemic, or health policies.  Therefore, the `health_mentioned` field is set to `false` and the `health_topics` list remains empty.
# Processed 550 / 1000
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# This speech focuses entirely on the political and economic consequences of Brexit. It does not discuss any health-related topics, including COVID-19, public health issues, vaccination, healthcare systems, hospitals, public health emergencies, disease control, pandemics, or health policies. The speaker's concerns are centered around economic and social impacts, particularly regarding marginalized communities.
# Processed 600 / 1000
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# The provided speech excerpt does not contain any explicit references to health, diseases, healthcare, public health issues, vaccination, pandemics, or related topics. It focuses solely on transatlantic cooperation, specifically NATO, and a personal reflection on a MEP's past work within the European Parliament. Therefore, all fields are set to `false` and the `health_topics` list remains empty.
# Processed 650 / 1000
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# This speech excerpt does not contain any direct references to health-related topics. It focuses entirely on geopolitical events (the assassination of Soleimani) and questions regarding military action.  Therefore, all health-related indicators are false.
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# This speech focuses entirely on the Brexit negotiations and the potential impact on citizens and businesses. There is no mention of COVID-19, public health, vaccination, healthcare systems, hospitals, a public health emergency, disease control, a pandemic, or health policies. Therefore, the `health_mentioned` flag is set to `false` and the `health_topics` list is empty.
# Processed 700 / 1000
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# This speech focuses entirely on infrastructure projects (canals), regulatory harmonization within river commissions, and maritime transport. There is absolutely no mention of any health-related topics such as COVID-19, public health, vaccination, healthcare systems, hospitals, public health emergencies, disease control, pandemics, or health policies. Therefore, the `health_mentioned` field is set to `false`, and the `health_topics` list is empty.
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# This speech focuses entirely on the political ramifications of the Irish election, Brexit, and related trade negotiations (specifically concerning fisheries).  It makes no mention of COVID-19, public health, healthcare, hospitals, or any related health topics or emergencies.  The discussion of "sustainable manner" and "sustainability priorities" relates to fisheries management, not public health.
# Processed 750 / 1000
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# The provided text focuses solely on the geopolitical conflict in Nagorno-Karabakh and does not discuss any aspects of health, public health, disease, healthcare, or related topics. Therefore, all the requested boolean and list fields are set to false and empty respectively.
# Processed 800 / 1000
# PARSING ERROR: Extra data: line 6 column 1 (char 56)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
# **Explanation:**
#
# The speech primarily focuses on political corruption, lobbying, and the economic consequences of the monetary union (specifically the Euro). While the speech implicitly touches on the economic impact of a crisis (implied through "shops that have closed, companies that have closed, citizens who have lost jobs"), it does *not* directly address COVID-19, public health issues, vaccination, healthcare systems, hospitals, a public health emergency, disease control, a pandemic, or health policies.  There's no mention of health-related concepts.
# Processed 850 / 1000
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# The speech excerpt does not contain any direct references to health, diseases, healthcare, public health, or related topics. It's a procedural comment about a parliamentary debate and contains no relevant information for the requested analysis. Therefore, all the `health_topics` fields are empty.
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# The speech focuses solely on the immigration crisis and the situation within the Moria camp.  It does not discuss any aspects of COVID-19, public health, vaccination, healthcare systems, hospitals, public health emergencies, disease control, pandemics, or health policies. The topic of the speech is immigration and humanitarian concerns related to the reception of migrants.
# Processed 900 / 1000
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# This speech does not directly discuss any of the specified health-related topics. It focuses entirely on the political and geopolitical situation surrounding Hong Kong and relations with China, specifically referencing sanctions and a historical analogy to communist regimes.  There is no mention of COVID-19, public health issues, vaccination, healthcare systems, hospitals, a public health emergency, disease control, a pandemic, or health policies.
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# The speech focuses entirely on police aggression and the treatment of law enforcement officers. It does not contain any discussion related to COVID-19, public health, vaccination, healthcare systems, hospitals, public health emergencies, disease control, pandemics, or health policies.  Therefore, the `health_mentioned` flag is set to `false` and the `health_topics` list is empty.
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# This speech focuses entirely on the Brexit negotiations and the future relationship between the EU and the UK. There is no mention of any health-related topics, including COVID-19, public health, vaccination, healthcare systems, hospitals, public health emergencies, disease control, pandemics, or health policies.
# Processed 950 / 1000
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# The provided speech snippet is extremely brief and lacks any explicit mention of health, diseases, or related topics. It's simply a response ("That would be an excellent idea") and doesn't relate to any of the specified categories. Therefore, the JSON indicates `health_mentioned: false` and an empty list `health_topics: []` because no relevant topics were discussed.
# PARSING ERROR: Extra data: line 7 column 1 (char 57)
# RAW OUTPUT: ```json
# {
#   "health_mentioned": false,
#   "health_topics": []
# }
# ```
#
# **Explanation:**
#
# This speech does not directly address any of the health-related topics requested. It focuses solely on geopolitical conflict between Armenia and Azerbaijan, referencing the Minsk Group, Russian foreign policy interventions, and calls for a Security Council resolution. There is no mention of COVID-19, public health, vaccination, healthcare systems, hospitals, a public health emergency, disease control, a pandemic, or health policies.

# %%
llm_df
# Out:
#     speaker_party health_mentioned  \
# 0             S&D             True
# 1      Greens/EFA             True
# 2             S&D             None
# 3             PPE             True
# 4              ID             None
# ..            ...              ...
# 995           PPE             True
# 996           PPE             None
# 997           S&D             None
# 998            ID             None
# 999           ECR             None
#
#                                          health_topics
# 0    [public health, healthcare systems, health pol...
# 1    [economic impact, social inequality, public he...
# 2                                                   []
# 3    [COVID-19, public health issues, healthcare sy...
# 4                                                   []
# ..                                                 ...
# 995  [COVID-19, public health issues, vaccination, ...
# 996                                                 []
# 997                                                 []
# 998                                                 []
# 999                                                 []
#
# [1000 rows x 3 columns]

# %%
llm_df.to_csv(
    "eu_debates_2020_llm_health_sample1000.csv",
    index=False
)
